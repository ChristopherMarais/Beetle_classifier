# %%
import os
import pandas as pd
import numpy as np

# %%
# get working directory
pwd = os.getcwd()
raw = r"E:\GIT_REPOS\Beetle_classifier\Data\raw\\"
species_test_dir = r"E:\GIT_REPOS\Beetle_classifier\Data\raw\Species\csv\test\\"
species_valid_known_dir = r"E:\GIT_REPOS\Beetle_classifier\Data\raw\Species\csv\valid\known\\"
species_valid_unknown_dir = r"E:\GIT_REPOS\Beetle_classifier\Data\raw\Species\csv\valid\unknown\\"

# %% [markdown]
# # Species

# %%
species_lst = ['Coccotypes_dactyliperda', 'Hylesinus_varius', 'Monarthrum_fasciatum',
                'Phloeosinus_dentatus', 'Pityophthorus_juglandis', 'Platypus_cylindrus',
                'Pycnarthrum_hispidium', 'Scolotodes_schwarzi', 'Xyleborinus_saxesenii',
                'Xyleborus_affinis', 'Xylosandrus_compactus',
                'Xylosandrus_crassiusculus']

# %%
df = pd.read_csv(species_test_dir+"Coccotypes_dactyliperda_Testing_prediction_probabilities_fold-1.csv").drop('Unnamed: 0', axis=1)
df
# Out:
#       Hylesinus_varius  Monarthrum_fasciatum  Phloeosinus_dentatus  \
# 0             0.007425              0.004185              0.004810
# 1             0.004655              0.004216              0.007556
# 2             0.005077              0.009514              0.007234
# 3             0.006554              0.003659              0.008379
# 4             0.007949              0.009542              0.011691
# ...                ...                   ...                   ...
# 3990          0.014186              0.013060              0.847780
# 3991          0.008772              0.011132              0.898611
# 3992          0.009305              0.013066              0.900278
# 3993          0.017103              0.016516              0.822374
# 3994          0.013733              0.013716              0.872187
#
#       Pityophthorus_juglandis  Platypus_cylindrus  Pycnarthrum_hispidium  \
# 0                    0.003915            0.003750               0.007485
# ...

# %%
df = pd.read_csv(species_valid_known_dir+"Coccotypes_dactyliperda_Validation_prediction_probabilities_fold-1.csv").drop('Unnamed: 0', axis=1)
df
# Out:
#       Hylesinus_varius  Monarthrum_fasciatum  Phloeosinus_dentatus  \
# 0             0.005503              0.010836              0.005626
# 1             0.007164              0.009942              0.008396
# 2             0.011795              0.006457              0.010419
# 3             0.007405              0.004223              0.008510
# 4             0.005859              0.006721              0.004356
# ...                ...                   ...                   ...
# 6273          0.013438              0.015286              0.847747
# 6274          0.012926              0.016844              0.821650
# 6275          0.012154              0.015727              0.746300
# 6276          0.020355              0.017802              0.828520
# 6277          0.010469              0.013611              0.846025
#
#       Pityophthorus_juglandis  Platypus_cylindrus  Pycnarthrum_hispidium  \
# 0                    0.003991            0.006497               0.007326
# ...

# %%
df = pd.read_csv(species_valid_unknown_dir+"Coccotypes_dactyliperda_Unknown_Validation_prediction_probabilities_fold-1.csv").drop('Unnamed: 0', axis=1)
df
# Out:
#       Hylesinus_varius  Monarthrum_fasciatum  Phloeosinus_dentatus  \
# 0             0.018919              0.017825              0.028596
# 1             0.022501              0.026280              0.008066
# 2             0.014042              0.022516              0.018813
# 3             0.022526              0.021951              0.049775
# 4             0.017983              0.024105              0.079384
# ...                ...                   ...                   ...
# 1068          0.032371              0.025985              0.045919
# 1069          0.019103              0.027457              0.016468
# 1070          0.009137              0.012934              0.011939
# 1071          0.020118              0.020635              0.047564
# 1072          0.026009              0.017841              0.030767
#
#       Pityophthorus_juglandis  Platypus_cylindrus  Pycnarthrum_hispidium  \
# 0                    0.040633            0.014534               0.151894
# ...
