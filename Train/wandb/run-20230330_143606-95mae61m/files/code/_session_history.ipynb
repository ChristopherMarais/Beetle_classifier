# %%
import timm
import torch
import wandb
import fastai
import dill
import numpy as np
from fastai.callback.wandb import *
from fastai.vision.all import *
from fastai.vision.core import *
from fastai.text.core import RegexLabeller
from fastai.vision.utils import get_image_files
from fastai.data.block import DataBlock
from fastai.data.core import *
from fastai.tabular.all import *
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from huggingface_hub import notebook_login, push_to_hub_fastai, from_pretrained_fastai
# os.environ['WANDB_WATCH'] = 'false'

# %%
config = SimpleNamespace(
    batch_size=64,  #16, #256,
    epochs=5,
    # learning_rate=2e-3,
    img_size=224,
    seed=42,
    pretrained=True,
    top_k_losses=5,
    model_name="maxvit_rmlp_small_rw_224.sw_in1k",# try with maxvit_nano_rw_256.sw_in1k # regnetx_040 coatnet_bn_0_rw_224.sw_in1k
    wandb_project="Beetle_classifier", 
    wandb_group="ambrosia_symbiosis",
    job_type="training"
    )

# %%
def get_images(dataset_path, batch_size, img_size, seed):
    "The beetles dataset"
    files = get_image_files(path=dataset_path, recurse=True, folders=('train','valid'))
    dblock = DataBlock(blocks = (ImageBlock, CategoryBlock),
                       get_items = get_image_files,
                       splitter = GrandparentSplitter(train_name='train', valid_name='valid'),
                       get_y = parent_label,
                       item_tfms = Resize(img_size, ResizeMethod.Pad, pad_mode='zeros'))
    dls = dblock.dataloaders(dataset_path, bs = batch_size)
    return dls

def train(config, dataset_path):
    "Train the model using the supplied config"
    dls = get_images(dataset_path=dataset_path, batch_size=config.batch_size, img_size=config.img_size, seed=config.seed)
    # wandb.init(project=config.wandb_project, group=config.wandb_group, job_type=config.job_type, config=config) # it is a good idea to keep these functions out of the training function due to some exporting issues
    cbs = [MixedPrecision(), ShowGraphCallback(), SaveModelCallback(), WandbCallback(log='gradients')] # (all, parameters, gradients or None) parameters and all does nto work currently wandb needs to be updated
    learn = vision_learner(dls, 
                           config.model_name, 
                           loss_func=LabelSmoothingCrossEntropyFlat(),
                           metrics=[error_rate, 
                                    accuracy, 
                                    top_k_accuracy], 
                           cbs=cbs, 
                           pretrained=config.pretrained)
    learn.fine_tune(config.epochs)
    interp = ClassificationInterpretation.from_learner(learn)
    interp.plot_confusion_matrix()
    interp.plot_top_losses(config.top_k_losses, nrows=config.top_k_losses)
    # wandb.finish() # it is a good idea to keep these functions out of the training function due to some exporting issues
    return learn

# this function only describes how much a singular value in al ist stands out.
# if all values in the lsit are high or low this is 1
# the smaller the proportiopn of number of disimilar vlaues are to other more similar values the lower this number
# the larger the gap between the dissimilar numbers and the simialr number the smaller this number
# only able to interpret probabilities or values between 0 and 1
# this function outputs an estimate an inverse of the classification confidence based on the probabilities of all the classes.
# the wedge threshold splits the data on a threshold with a magnitude of a positive int to force a ledge/peak in the data
def unkown_prob_calc(probs, wedge_threshold, wedge_magnitude=1, wedge=True):
    if wedge:
        probs = np.where(probs<=wedge_threshold , probs**(2*wedge_magnitude), probs)
        probs = np.where(probs>=wedge_threshold , probs**(1/(2*wedge_magnitude)), probs)
    diff_matrix = np.abs(probs[:, np.newaxis] - probs)
    diff_matrix_sum = np.sum(diff_matrix)
    probs_sum = np.sum(probs)
    class_val = (diff_matrix_sum/probs_sum)
    max_class_val = ((len(probs)-1)*2)
    kown_prob = class_val/max_class_val
    unknown_prob = 1-kown_prob
    return(unknown_prob)

# %%
# Train Model
wandb.init(project=config.wandb_project, group=config.wandb_group, job_type=config.job_type, config=config)
learn = train(config=config, dataset_path=r"/blue/hulcr/gmarais/Beetle_data/selected_images/train_data")
wandb.finish()
# Out:
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>/blue/hulcr/gmarais/Beetle_classifier/Train/wandb/run-20230330_143606-95mae61m</code>
# Syncing run <strong><a href='https://wandb.ai/christopher-marais/Beetle_classifier/runs/95mae61m' target="_blank">super-tree-9</a></strong> to <a href='https://wandb.ai/christopher-marais/Beetle_classifier' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/christopher-marais/Beetle_classifier' target="_blank">https://wandb.ai/christopher-marais/Beetle_classifier</a>
#  View run at <a href='https://wandb.ai/christopher-marais/Beetle_classifier/runs/95mae61m' target="_blank">https://wandb.ai/christopher-marais/Beetle_classifier/runs/95mae61m</a>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='0' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/292 00:00&lt;?]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='1' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.34% [1/292 00:19&lt;1:35:40]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='2' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.68% [2/292 00:19&lt;48:09 3.6660]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='3' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       1.03% [3/292 00:20&lt;32:40 3.5688]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='4' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       1.37% [4/292 00:20&lt;24:39 3.5091]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='5' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       1.71% [5/292 00:20&lt;19:50 3.4419]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='6' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       2.05% [6/292 00:20&lt;16:37 3.4900]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='7' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       2.40% [7/292 00:21&lt;14:19 3.5651]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='8' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       2.74% [8/292 00:21&lt;12:36 3.5680]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='9' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       3.08% [9/292 00:21&lt;11:16 3.5491]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='10' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       3.42% [10/292 00:21&lt;10:12 3.5746]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='11' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       3.77% [11/292 00:21&lt;09:20 3.5524]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='12' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       4.11% [12/292 00:22&lt;08:36 3.5517]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='13' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       4.45% [13/292 00:22&lt;07:59 3.5542]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='14' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       4.79% [14/292 00:22&lt;07:27 3.5426]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='15' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       5.14% [15/292 00:22&lt;06:59 3.5159]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='16' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       5.48% [16/292 00:22&lt;06:35 3.5010]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='17' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       5.82% [17/292 00:23&lt;06:14 3.4822]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='18' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       6.16% [18/292 00:23&lt;05:55 3.4652]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='19' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       6.51% [19/292 00:23&lt;05:38 3.4215]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='20' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       6.85% [20/292 00:23&lt;05:22 3.3825]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='21' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       7.19% [21/292 00:23&lt;05:08 3.3673]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='22' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       7.53% [22/292 00:24&lt;04:56 3.3701]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='23' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       7.88% [23/292 00:24&lt;04:44 3.3551]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='24' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       8.22% [24/292 00:24&lt;04:34 3.3077]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='25' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       8.56% [25/292 00:24&lt;04:24 3.2697]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='26' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       8.90% [26/292 00:24&lt;04:15 3.2384]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='27' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       9.25% [27/292 00:25&lt;04:06 3.2017]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='28' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       9.59% [28/292 00:25&lt;03:58 3.1745]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='29' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       9.93% [29/292 00:25&lt;03:51 3.1394]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='30' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       10.27% [30/292 00:25&lt;03:44 3.1073]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='31' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       10.62% [31/292 00:25&lt;03:38 3.0721]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='32' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       10.96% [32/292 00:26&lt;03:32 3.0448]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='33' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       11.30% [33/292 00:26&lt;03:26 3.0077]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='34' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       11.64% [34/292 00:26&lt;03:21 2.9725]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='35' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       11.99% [35/292 00:26&lt;03:16 2.9441]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='36' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       12.33% [36/292 00:26&lt;03:11 2.9231]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='37' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       12.67% [37/292 00:27&lt;03:07 2.8980]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='38' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       13.01% [38/292 00:27&lt;03:02 2.8771]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='39' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       13.36% [39/292 00:27&lt;02:58 2.8613]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='40' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       13.70% [40/292 00:27&lt;02:54 2.8381]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='41' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       14.04% [41/292 00:27&lt;02:51 2.8028]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='42' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       14.38% [42/292 00:28&lt;02:47 2.7910]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='43' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       14.73% [43/292 00:28&lt;02:44 2.7757]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='44' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       15.07% [44/292 00:28&lt;02:41 2.7440]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='45' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       15.41% [45/292 00:28&lt;02:37 2.7245]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='46' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       15.75% [46/292 00:28&lt;02:34 2.6996]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='47' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       16.10% [47/292 00:29&lt;02:32 2.6757]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='48' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       16.44% [48/292 00:29&lt;02:29 2.6416]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='49' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       16.78% [49/292 00:29&lt;02:26 2.6173]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='50' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       17.12% [50/292 00:29&lt;02:24 2.5893]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='51' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       17.47% [51/292 00:29&lt;02:21 2.5632]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='52' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       17.81% [52/292 00:30&lt;02:19 2.5347]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='53' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       18.15% [53/292 00:30&lt;02:17 2.5226]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='54' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       18.49% [54/292 00:30&lt;02:14 2.5014]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='55' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       18.84% [55/292 00:30&lt;02:12 2.4815]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='56' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       19.18% [56/292 00:30&lt;02:10 2.4505]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='57' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       19.52% [57/292 00:31&lt;02:08 2.4233]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='58' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       19.86% [58/292 00:31&lt;02:06 2.3934]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='59' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.21% [59/292 00:31&lt;02:04 2.3686]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='60' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.55% [60/292 00:31&lt;02:02 2.3440]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='61' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.89% [61/292 00:31&lt;02:01 2.3238]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='62' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       21.23% [62/292 00:32&lt;01:59 2.3047]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='63' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       21.58% [63/292 00:32&lt;01:57 2.2987]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='64' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       21.92% [64/292 00:32&lt;01:56 2.2761]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='65' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       22.26% [65/292 00:32&lt;01:54 2.2534]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='66' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       22.60% [66/292 00:32&lt;01:52 2.2331]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='67' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       22.95% [67/292 00:33&lt;01:51 2.2127]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='68' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       23.29% [68/292 00:33&lt;01:50 2.1885]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='69' class='' max='292' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       23.63% [69/292 00:33&lt;01:48 2.1686]
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>top_k_accuracy</th>
# ...
#       9.78% [9/92 00:03&lt;00:29 0.5309]
#     </div>
#     <div>
#       <progress value='10' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       10.87% [10/92 00:03&lt;00:26 0.5309]
#     </div>
#     <div>
#       <progress value='11' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       11.96% [11/92 00:03&lt;00:24 0.5309]
#     </div>
#     <div>
#       <progress value='12' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       13.04% [12/92 00:03&lt;00:22 0.5309]
#     </div>
#     <div>
#       <progress value='13' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       14.13% [13/92 00:03&lt;00:22 0.5309]
#     </div>
#     <div>
#       <progress value='14' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       15.22% [14/92 00:03&lt;00:21 0.5309]
#     </div>
#     <div>
#       <progress value='15' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       16.30% [15/92 00:03&lt;00:19 0.5309]
#     </div>
#     <div>
#       <progress value='16' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       17.39% [16/92 00:03&lt;00:18 0.5309]
#     </div>
#     <div>
#       <progress value='17' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       18.48% [17/92 00:04&lt;00:18 0.5309]
#     </div>
#     <div>
#       <progress value='18' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       19.57% [18/92 00:04&lt;00:17 0.5309]
#     </div>
#     <div>
#       <progress value='19' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.65% [19/92 00:04&lt;00:16 0.5309]
#     </div>
#     <div>
#       <progress value='20' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       21.74% [20/92 00:04&lt;00:15 0.5309]
#     </div>
#     <div>
#       <progress value='21' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       22.83% [21/92 00:04&lt;00:15 0.5309]
#     </div>
#     <div>
#       <progress value='22' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       23.91% [22/92 00:04&lt;00:14 0.5309]
#     </div>
#     <div>
#       <progress value='23' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       25.00% [23/92 00:04&lt;00:14 0.5309]
#     </div>
#     <div>
#       <progress value='24' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       26.09% [24/92 00:04&lt;00:13 0.5309]
#     </div>
#     <div>
#       <progress value='25' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       27.17% [25/92 00:04&lt;00:13 0.5309]
#     </div>
#     <div>
#       <progress value='26' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       28.26% [26/92 00:04&lt;00:12 0.5309]
#     </div>
#     <div>
#       <progress value='27' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       29.35% [27/92 00:05&lt;00:12 0.5309]
#     </div>
#     <div>
#       <progress value='28' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       30.43% [28/92 00:05&lt;00:11 0.5309]
#     </div>
#     <div>
#       <progress value='29' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       31.52% [29/92 00:05&lt;00:11 0.5309]
#     </div>
#     <div>
#       <progress value='30' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       32.61% [30/92 00:05&lt;00:11 0.5309]
#     </div>
#     <div>
#       <progress value='31' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       33.70% [31/92 00:05&lt;00:10 0.5309]
#     </div>
#     <div>
#       <progress value='32' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       34.78% [32/92 00:05&lt;00:10 0.5309]
#     </div>
#     <div>
#       <progress value='33' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       35.87% [33/92 00:05&lt;00:10 0.5309]
#     </div>
#     <div>
#       <progress value='34' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       36.96% [34/92 00:05&lt;00:09 0.5309]
#     </div>
#     <div>
#       <progress value='35' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       38.04% [35/92 00:05&lt;00:09 0.5309]
#     </div>
#     <div>
#       <progress value='36' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       39.13% [36/92 00:06&lt;00:09 0.5309]
#     </div>
#     <div>
#       <progress value='37' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       40.22% [37/92 00:06&lt;00:09 0.5309]
#     </div>
#     <div>
#       <progress value='38' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       41.30% [38/92 00:06&lt;00:08 0.5309]
#     </div>
#     <div>
#       <progress value='39' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       42.39% [39/92 00:06&lt;00:08 0.5309]
#     </div>
#     <div>
#       <progress value='40' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       43.48% [40/92 00:06&lt;00:08 0.5309]
#     </div>
#     <div>
#       <progress value='41' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       44.57% [41/92 00:06&lt;00:08 0.5309]
#     </div>
#     <div>
#       <progress value='42' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       45.65% [42/92 00:06&lt;00:08 0.5309]
#     </div>
#     <div>
#       <progress value='43' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       46.74% [43/92 00:06&lt;00:07 0.5309]
#     </div>
#     <div>
#       <progress value='44' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       47.83% [44/92 00:06&lt;00:07 0.5309]
#     </div>
#     <div>
#       <progress value='45' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       48.91% [45/92 00:07&lt;00:07 0.5309]
#     </div>
#     <div>
#       <progress value='46' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [46/92 00:07&lt;00:07 0.5309]
#     </div>
#     <div>
#       <progress value='47' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       51.09% [47/92 00:07&lt;00:06 0.5309]
#     </div>
#     <div>
#       <progress value='48' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       52.17% [48/92 00:07&lt;00:06 0.5309]
#     </div>
#     <div>
#       <progress value='49' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       53.26% [49/92 00:07&lt;00:06 0.5309]
#     </div>
#     <div>
#       <progress value='50' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       54.35% [50/92 00:07&lt;00:06 0.5309]
#     </div>
#     <div>
#       <progress value='51' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       55.43% [51/92 00:07&lt;00:06 0.5309]
#     </div>
#     <div>
#       <progress value='52' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       56.52% [52/92 00:07&lt;00:06 0.5309]
#     </div>
#     <div>
#       <progress value='53' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       57.61% [53/92 00:07&lt;00:05 0.5309]
#     </div>
#     <div>
#       <progress value='54' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       58.70% [54/92 00:08&lt;00:05 0.5309]
#     </div>
#     <div>
#       <progress value='55' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       59.78% [55/92 00:08&lt;00:05 0.5309]
#     </div>
#     <div>
#       <progress value='56' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       60.87% [56/92 00:08&lt;00:05 0.5309]
#     </div>
#     <div>
#       <progress value='57' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       61.96% [57/92 00:08&lt;00:05 0.5309]
#     </div>
#     <div>
#       <progress value='58' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       63.04% [58/92 00:08&lt;00:05 0.5309]
#     </div>
#     <div>
#       <progress value='59' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       64.13% [59/92 00:08&lt;00:04 0.5309]
#     </div>
#     <div>
#       <progress value='60' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       65.22% [60/92 00:08&lt;00:04 0.5309]
#     </div>
#     <div>
#       <progress value='61' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.30% [61/92 00:08&lt;00:04 0.5309]
#     </div>
#     <div>
#       <progress value='62' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       67.39% [62/92 00:09&lt;00:04 0.5309]
#     </div>
#     <div>
#       <progress value='63' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       68.48% [63/92 00:09&lt;00:04 0.5309]
#     </div>
#     <div>
#       <progress value='64' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       69.57% [64/92 00:09&lt;00:04 0.5309]
#     </div>
#     <div>
#       <progress value='65' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       70.65% [65/92 00:09&lt;00:03 0.5309]
#     </div>
#     <div>
#       <progress value='66' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       71.74% [66/92 00:09&lt;00:03 0.5309]
#     </div>
#     <div>
#       <progress value='67' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       72.83% [67/92 00:09&lt;00:03 0.5309]
#     </div>
#     <div>
#       <progress value='68' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       73.91% [68/92 00:09&lt;00:03 0.5309]
#     </div>
#     <div>
#       <progress value='69' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       75.00% [69/92 00:10&lt;00:03 0.5309]
#     </div>
#     <div>
#       <progress value='70' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       76.09% [70/92 00:10&lt;00:03 0.5309]
#     </div>
#     <div>
#       <progress value='71' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       77.17% [71/92 00:10&lt;00:03 0.5309]
#     </div>
#     <div>
#       <progress value='72' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       78.26% [72/92 00:10&lt;00:02 0.5309]
#     </div>
#     <div>
#       <progress value='73' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       79.35% [73/92 00:11&lt;00:02 0.5309]
#     </div>
#     <div>
#       <progress value='74' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       80.43% [74/92 00:11&lt;00:02 0.5309]
#     </div>
#     <div>
#       <progress value='75' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       81.52% [75/92 00:11&lt;00:02 0.5309]
#     </div>
#     <div>
#       <progress value='76' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       82.61% [76/92 00:11&lt;00:02 0.5309]
#     </div>
#     <div>
#       <progress value='77' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       83.70% [77/92 00:11&lt;00:02 0.5309]
#     </div>
#     <div>
#       <progress value='78' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       84.78% [78/92 00:11&lt;00:02 0.5309]
#     </div>
#     <div>
#       <progress value='79' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       85.87% [79/92 00:11&lt;00:01 0.5309]
#     </div>
#     <div>
#       <progress value='80' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       86.96% [80/92 00:11&lt;00:01 0.5309]
#     </div>
#     <div>
#       <progress value='81' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       88.04% [81/92 00:11&lt;00:01 0.5309]
#     </div>
#     <div>
#       <progress value='82' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       89.13% [82/92 00:12&lt;00:01 0.5309]
#     </div>
#     <div>
#       <progress value='83' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       90.22% [83/92 00:12&lt;00:01 0.5309]
#     </div>
#     <div>
#       <progress value='84' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       91.30% [84/92 00:12&lt;00:01 0.5309]
#     </div>
#     <div>
#       <progress value='85' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       92.39% [85/92 00:12&lt;00:01 0.5309]
#     </div>
#     <div>
#       <progress value='86' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       93.48% [86/92 00:12&lt;00:00 0.5309]
#     </div>
#     <div>
#       <progress value='87' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       94.57% [87/92 00:12&lt;00:00 0.5309]
#     </div>
#     <div>
#       <progress value='88' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       95.65% [88/92 00:12&lt;00:00 0.5309]
#     </div>
#     <div>
#       <progress value='89' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       96.74% [89/92 00:12&lt;00:00 0.5309]
#     </div>
#     <div>
#       <progress value='90' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       97.83% [90/92 00:13&lt;00:00 0.5309]
#     </div>
#     <div>
#       <progress value='91' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       98.91% [91/92 00:13&lt;00:00 0.5309]
#     </div>
#     <div>
#       <progress value='92' class='' max='92' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [92/92 00:13&lt;00:00 0.5309]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#     <div>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:01&lt;00:00]
#     </div>
